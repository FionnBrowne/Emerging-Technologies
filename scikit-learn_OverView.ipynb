# %% [markdown]
# A clear and concise overview of the scikit-learn Python library

# %% [markdown]
# 1. What is scikit-learn
# 2. Who uses it
# 3. Why is it used
# 4. Why are we using it
# 5. Conclusion
# 6. References

# %% [markdown]
# # **What is sckit-learn**
# ***

# %% [markdown]
# **Sklearn** or *scikit-learn* in Python is by far one of the most useful open-source libraries available that you can use for **Machine Learning** in **Python**. The *scikit-learn library* is an exhaustive collection of the most efficient tools for *statistical modeling* and *Machine Learning*. These tools include **regression**, **classification**, **dimensionality reduction**, and **clustering**.<br>
# The *scikit-learn library* is primarily written in **Python** and built upon **SciPy**, **NumPy**, and **Matplotlib**. The library uses a *unified* and *consistent* Python interface to implement various **pre-processing**, **Machine Learning**, **visualization**, and **cross-validation algorithms**.

# %% [markdown]
# # **Who uses it**
# ***

# %% [markdown]
# Here are some of the more prominent companies that use scikit-learn.
#
# | Spotify | Booking.com   | AWeber | OkCupid   |
# |------|------|------|------|
# | <img src="images/spotify.jpg" width="300"> | <img src="images/Booking.com.jpg"  width="400"> | <img src="images/AWeber.jpg" width="300"> | <img src="images/OkCupid.jpg" width="320"> |
# ***
# 1. Spotify uses scikit-learn
#    - For recommendations of music by using decision Tree.
#      - It takes in values such as energy, tempo, danceability, and valence for each song and allows an Optimal Parameters (accuracy = 0.9063)
#        - It uses a toolbox with solid implementations of many state-of-the-art models, which is provided by scikit-learn.
#          - This makes it easy to plug the models into existing applications.
# ***
# 2. Booking.com uses scikit-learn
#    - For their predictions tasks.
#      - This is then fed into there algothrims
#        - Prediction(X) = 𝓕(<W, 𝓣(X)>)  Where <,> means the inner product, X is the input vector, W is the weight vector (the model), 𝓕 is the inverted link function (scalar to scalar), and 𝓣 is a vector to vector transformation applied before the inner product is computed. Finally, the output is a single scalar.
# ***
# 3. AWeber uses scikit-learn
#    - For Real-time Predictive Analytics
#      - It achieves this and much more using the text feature extraction utilities for working with the large volume of email content, the RandomizedPCA implementation, along with Pipelining and FeatureUnions to develop complex machine learning algorithms.
# ***
# 4. OkCupid uses scikit-learn
#    - For evaluating and improving their matchmaking system
#      - It can handle large amounts of data and with good performance, especially with pre-processing utilities
# ***

# %% [markdown]
# # **Why is it used**
# ***

# %% [markdown]
# Scikit-learn is probably the most helpful library for machine learning in Python. The sklearn library contains a lot of efficient tools for machine learning and statistical modeling, including classification, regression, clustering, and dimensionality reduction.

# %% [markdown]
# # **Why are we using it**
# ***

# %% [markdown]
# ( --- )

# %% [markdown]
# # **Conclusion**
# ***

# %% [markdown]
# Scikit-learn is a potent tool to perform calculations using algothrims on classification, regression, clustering, and dimensionality reduction.
# <br>
# <p align="center">
#     <img width="900" src="images/sklearn.png"  >
# </p>

# %% [markdown]
# ***
# # Here are three small example of how to use it
# ***

# %% [markdown]
# # Example 1
# ***

# %%
# Efficent numerical arrays.
import numpy as np

# Plotting.
import matplotlib.pyplot as plt

# %%
# Change default style sheet.
plt.style.use('fivethirtyeight')

# Change the default figure size
plt.rcParams['figure.figsize'] = [16, 8]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# look at the first ten items
s[:10]
# Out:
# array([ 0.02099569, -0.05991328,  0.1635496 , -0.09567437,  0.00928886,
#        -0.22326813, -0.13046814, -0.28104378, -0.02055333,  0.06597392])

# %%
abs(mu - np.mean(s))
# Out:
# 0.000590808642013772

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.004801030032452899

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu)**2/(2 * sigma**2))
plt.plot(bins, f , linewidth=2)
plt.show()

# %% [markdown]
# ## References
# [1] https://www.datacamp.com/community/tutorials/numpy-random

# %% [markdown]
# ***
# ## Example 2
# ***

# %%
import sklearn.datasets as datasets
iris = datasets.load_iris()
digits = datasets.load_digits()
print(digits.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100.)
clf.fit(digits.data[:-1], digits.target[:-1])
# Out:
# SVC(C=100.0, gamma=0.001)

# %%
clf.predict(digits.data[-1:])
# Out:
# array([8])

# %% [markdown]
# https://scikit-learn.org/stable/tutorial/index.html
# ***

# %% [markdown]
# # Example 3 checking datasets and visualising
# ***

# %%
# Handeling all imports for this notebook
# Numerical arrays.
import numpy as np

# Data frames.
import pandas as pd

# Plotting.
import matplotlib.pyplot as plt

# Fancier, statistical plots. good visualizing
import seaborn as sns

import itertools

import warnings

# Standard plot size.
plt.rcParams['figure.figsize'] = (15,10)

# Standard colour scheme.
plt.style.use('ggplot')

# %%
# Load the data set from github url.
data = pd.read_csv("https://raw.githubusercontent.com/FionnBrowne/Emerging-Technologies/main/Algothrim's_CSV/winequality-red.csv", sep=";")
# Displaying the data.
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Summary statistics.
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#correlation map view
data.corr() 
# New figure & subplot.
fig, ax = plt.subplots(figsize = (16,16))
# visualise using heat colours and to 3 decimal places
sns.heatmap(data.corr(), annot = True, linewidths=.5, fmt = ".3f", ax=ax)
plt.show()

# %% [markdown]
# # References
# ***

# %% [markdown]
# https://docs.github.com/en/github/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax<br>
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html<br>
# https://www.earthdatascience.org/courses/intro-to-earth-data-science/file-formats/use-text-files/format-text-with-markdown-jupyter-notebook/<br>
# https://www.analyticsvidhya.com/blog/2015/01/scikit-learn-python-machine-learning-tool/<br>
